# %%
# !python --version
# Out:
# Python 3.11.12

# %%
# !pip install pykrx
# Out:
# Collecting pykrx
#   Downloading pykrx-1.0.51-py3-none-any.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pykrx) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pykrx) (2.2.2)
# Collecting datetime (from pykrx)
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pykrx) (2.0.2)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.11/dist-packages (from pykrx) (2.0.1)
# Collecting deprecated (from pykrx)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from pykrx) (1.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pykrx) (3.10.0)
# Collecting zope.interface (from datetime->pykrx)
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from datetime->pykrx) (2025.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->pykrx) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pykrx) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pykrx) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pykrx) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pykrx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pykrx) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pykrx) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pykrx) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface->datetime->pykrx) (75.2.0)
# Downloading pykrx-1.0.51-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 29.2 MB/s eta 0:00:00
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 4.2 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: zope.interface, deprecated, datetime, pykrx
# Successfully installed datetime-5.5 deprecated-1.2.18 pykrx-1.0.51 zope.interface-7.2

# %%
# !pip install yfinance pandas numpy
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.61)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.11/dist-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)

# %%
# 1. 나눔 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum -qq

# 2. 폰트 캐시 업데이트 및 matplotlib 캐시 삭제
# !fc-cache -fv
# !rm -rf ~/.cache/matplotlib

# 3. matplotlib에 폰트 설정
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 나눔고딕 폰트 경로 설정
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# 폰트 직접 등록 방법
fe = fm.FontEntry(
    fname=font_path,
    name='NanumGothic')
fm.fontManager.ttflist.insert(0, fe)

# 폰트 설정 적용
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 표시 문제 해결

# 폰트 매니저 재구성 (제거됨)
# fm._rebuild() # This line is removed
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# !pip install pandas_market_calendars
# Out:
# Collecting pandas_market_calendars
#   Downloading pandas_market_calendars-5.1.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2.2.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from pandas_market_calendars) (2.9.0.post0)
# Collecting exchange-calendars>=3.3 (from pandas_market_calendars)
#   Downloading exchange_calendars-4.10.1-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (2.0.2)
# Collecting pyluach (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (0.12.1)
# Collecting korean_lunar_calendar (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->pandas_market_calendars) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->pandas_market_calendars) (1.17.0)
# Downloading pandas_market_calendars-5.1.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 8.3 MB/s eta 0:00:00
# Downloading exchange_calendars-4.10.1-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 15.2 MB/s eta 0:00:00
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: korean_lunar_calendar, pyluach, exchange-calendars, pandas_market_calendars
# Successfully installed exchange-calendars-4.10.1 korean_lunar_calendar-0.3.1 pandas_market_calendars-5.1.0 pyluach-2.2.0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/drive

# %%
print(yfinance.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e4b7ca8ff433> in <cell line: 0>()
# ----> 1 print(yfinance.__version__)
#
# NameError: name 'yfinance' is not defined

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import pandas_market_calendars as mcal
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import warnings
import time
import os
from bs4 import BeautifulSoup
import requests
from sklearn.preprocessing import RobustScaler

# GPU 라이브러리 추가
try:
    import cupy as cp
    import cudf
    import cuml
    HAS_GPU = True
    print("GPU 라이브러리 로드 성공 - GPU 가속 사용 가능")
except ImportError:
    HAS_GPU = False
    print("GPU 라이브러리 사용 불가 - CPU 처리로 진행합니다")
# 경고 메시지 무시
warnings.filterwarnings('ignore')

class DailyStockFactorModel:
    def __init__(self):
        print("일별 5팩터 모델 데이터 처리 시작")
        self.start_time = time.time()

        # 현재 날짜 설정
        self.current_date = datetime.now()
        # 1년 전 날짜 계산
        self.one_year_ago = self.current_date - relativedelta(years=1)

        # 한국/미국 대표 주식 리스트
        self.kr_stocks = []
        self.us_stocks = []

        # 데이터 저장용 변수
        self.stock_data = {} # stock_data 속성 추가
        self.daily_dates = []
        self.factor_model_data = pd.DataFrame()

        # 기본 베타값 딕셔너리 (API에서 가져오지 못할 경우 사용)
        self.default_beta_values = {
            '005935.KS': 0.85, '051910.KS': 1.25, '006400.KS': 1.30,
            '035720.KS': 1.35, '028260.KS': 1.10, '066570.KS': 1.15,
            '032830.KS': 0.80, '000810.KS': 0.75, '009150.KS': 1.05,
            '018260.KS': 0.95, '017670.KS': 0.90, '034730.KS': 1.00,
            '003550.KS': 1.10, '036570.KS': 1.40, '015760.KS': 0.65,
            '259960.KS': 1.50, '009540.KS': 1.20, '005490.KS': 1.05,
            '055550.KS': 0.95, '323410.KS': 1.30, '316140.KS': 0.85,
            '086790.KS': 0.90, '097950.KS': 1.10, '030200.KS': 0.75,
            '003670.KS': 1.15, '096770.KS': 1.25, '000100.KS': 0.80,
            '033780.KS': 0.85, '138040.KS': 0.95, '139480.KS': 0.70,
            '000020.KS': 0.83
        }

        # 팩터 가중치 설정
        self.factor_weights = {
            'Beta_Factor': 0.20,
            'Value_Factor': 0.20,
            'Size_Factor': 0.20,
            'Momentum_Factor': 0.20,
            'Volatility_Factor': 0.20
        }

    def get_exchange_rate_krw_to_usd(self):
        """KRW to USD 환율을 가져옵니다"""
        try:
            url = "https://api.exchangerate-api.com/v4/latest/USD"
            response = requests.get(url)
            data = response.json()

            usd_to_krw = data['rates']['KRW']
            krw_to_usd = 1 / usd_to_krw

            print(f"현재 환율: 1 USD = {usd_to_krw:.2f} KRW, 1 KRW = {krw_to_usd:.8f} USD")
            return krw_to_usd
        except Exception as e:
            print(f"환율 정보 가져오기 실패: {e}, 기본 환율 사용")
            return 0.00077

    def get_trading_days(self, start_date, end_date, market='KRX'):
        """특정 기간의 모든 거래일을 찾습니다"""
        try:
            # 해당 시장의 캘린더 생성
            if market == 'KRX':
                exchange = mcal.get_calendar('XKRX')
            else: # 미국 시장
                exchange = mcal.get_calendar('NYSE')

            # 해당 기간의 거래일 가져오기
            trading_days = exchange.valid_days(start_date=start_date, end_date=end_date)

            # 날짜 객체로 변환
            trading_days = [day.date() for day in trading_days]

            return trading_days
        except Exception as e:
            print(f"거래일 정보 가져오기 실패: {e}")
            return []

    def generate_daily_dates(self, market='KRX'):
        """지난 1년간의 모든 거래일 목록을 생성합니다"""
        start_date = self.one_year_ago.strftime('%Y-%m-%d')
        end_date = self.current_date.strftime('%Y-%m-%d')

        trading_days = self.get_trading_days(start_date, end_date, market)

        print(f"{market} 시장의 지난 1년간 거래일 {len(trading_days)}개 찾음")

        # 일별 날짜 저장
        self.daily_dates = trading_days
        return trading_days

    def get_korean_stocks(self, csv_path='/content/sample_data/KR_Stock_Master (1).csv'):
        print("\n한국 대표 주식 가져오기...")
        # CSV 파일 로드
        df = pd.read_csv(csv_path, dtype={'Code': str})

        # 종목코드 6자리로 맞추기
        df['Code'] = df['Code'].str.zfill(6)

        # Market에 따라 suffix 붙이기
        def add_suffix(row):
            market = str(row['Market']).strip().upper()
            if market == 'KOSPI':
                return row['Code'] + '.KS'
            elif market == 'KOSDAQ' or market == 'KOSDAQ GLOBAL':
                return row['Code'] + '.KQ'
            else:
                return row['Code']

        df['symbol'] = df.apply(add_suffix, axis=1)
        df['name'] = df['Name']

        # 원하는 컬럼만 추출
        self.kr_stocks = df[['symbol', 'name']].to_dict('records')

        print(f"한국 주식 {len(self.kr_stocks)}개 로드 완료")
        return self.kr_stocks

    def get_us_stocks(self, csv_path='/content/sample_data/US_Stock_Master (1).csv'):
        print("\n미국 대표 주식 가져오기...")
        # CSV 파일 로드
        df = pd.read_csv(csv_path, dtype={'ACT Symbol': str})

        # 결측값 제거 (심볼이나 이름이 없는 행 제외)
        df = df[['ACT Symbol', 'Company Name']].dropna(subset=['ACT Symbol', 'Company Name'])

        # 컬럼명 통일
        df = df.rename(columns={'ACT Symbol': 'symbol', 'Company Name': 'name'})

        # 딕셔너리 리스트로 변환
        self.us_stocks = df.to_dict('records')

        print(f"미국 주식 {len(self.us_stocks)}개 로드 완료")
        return self.us_stocks

    def get_beta_from_naver_scraping(self, symbol):
        """네이버 금융 웹 스크래핑으로 베타(Beta) 정보를 가져옵니다"""
        try:
            stock_code = symbol.split('.')[0]
            url = f"https://finance.naver.com/item/main.naver?code={stock_code}"
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
                'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7'
            }

            response = requests.get(url, headers=headers, timeout=(5,30))
            if response.status_code != 200:
                return None

            soup = BeautifulSoup(response.text, 'html.parser')

            # 베타값 찾기 시도 1: 테이블에서 베타값 찾기
            beta_element = soup.select_one("table:contains('베타') td.num") or soup.select_one("table:contains('β') td.num")
            if beta_element and beta_element.text.strip():
                beta_text = beta_element.text.strip()
                beta_text = ''.join(c for c in beta_text if c.isdigit() or c == '.' or c == '-')
                if beta_text and beta_text != '-':
                    beta = float(beta_text)
                    if beta > 0:
                        print(f"{symbol}: 네이버 금융에서 베타값 {beta:.4f} 가져옴")
                        return beta

            # 베타값 찾기 시도 2: 다른 방식으로 시도
            # 네이버 금융의 경우 "aws"라는 클래스가 있는 표에 베타값이 포함되어 있을 수 있음
            aws_tables = soup.find_all("table", class_="aws")
            for table in aws_tables:
                rows = table.find_all("tr")
                for row in rows:
                    cols = row.find_all("td")
                    for i, col in enumerate(cols):
                        if '베타' in col.text or 'β' in col.text:
                            if i+1 < len(cols) and cols[i+1].text.strip():
                                beta_text = cols[i+1].text.strip()
                                beta_text = ''.join(c for c in beta_text if c.isdigit() or c == '.' or c == '-')
                                if beta_text and beta_text != '-':
                                    beta = float(beta_text)
                                    if beta > 0:
                                        print(f"{symbol}: 네이버 금융에서 베타값 {beta:.4f} 가져옴")
                                        return beta

            return None
        except Exception as e:
            print(f"{symbol}: 베타값 스크래핑 중 오류 발생 - {e}")
            return None

    def get_pbr_from_naver_scraping(self, symbol):
        """네이버 금융 웹 스크래핑으로 PBR 정보를 가져옵니다"""
        try:
            stock_code = symbol.split('.')[0]
            url = f"https://finance.naver.com/item/main.naver?code={stock_code}"
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
                'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7'
            }

            response = requests.get(url, headers=headers, timeout=(5,30))
            if response.status_code != 200:
                return None

            soup = BeautifulSoup(response.text, 'html.parser')
            pbr_element = soup.select_one("table:contains('PBR') td.num")
            if pbr_element and pbr_element.text.strip():
                pbr_text = pbr_element.text.strip()
                pbr_text = ''.join(c for c in pbr_text if c.isdigit() or c == '.' or c == '-')
                if pbr_text and pbr_text != '-':
                    pbr = float(pbr_text)
                    if pbr > 0:
                        print(f"{symbol}: 네이버 금융에서 PBR값 {pbr:.4f} 가져옴")
                        return pbr

            # 다른 방식으로도 시도
            pbr_selector = "#_pbr"
            pbr_element = soup.select_one(pbr_selector)
            if pbr_element and pbr_element.text.strip():
                pbr_text = pbr_element.text.strip()
                pbr_text = ''.join(c for c in pbr_text if c.isdigit() or c == '.' or c == '-')
                if pbr_text and pbr_text != '-':
                    pbr = float(pbr_text)
                    if pbr > 0:
                        print(f"{symbol}: 네이버 금융에서 PBR값 {pbr:.4f} 가져옴")
                        return pbr

            return None
        except Exception:
            return None

    def calculate_indicators_for_stock(self, symbol, name, daily_dates, market_index):
        """특정 종목의 일별 지표를 계산합니다"""
        results = []

        try:
            # 데이터 다운로드 기간 설정 (충분한 데이터를 위해 여유 있게 설정)
            start_date = min(daily_dates) - relativedelta(months=15)
            end_date = max(daily_dates) + relativedelta(days=5)

            # 히스토리 데이터 다운로드 - auto_adjust=False, multi_level_index=False 설정
            hist_data = yf.download(symbol, start=start_date, end=end_date, progress=False,
                                   auto_adjust=False, multi_level_index=False)

            time.sleep(1)

            if len(hist_data) < 30:
                print(f"{symbol}: 데이터가 충분하지 않습니다 (행 수: {len(hist_data)})")
                return []

            # 시장 지수 데이터 다운로드
            index_data = yf.download(market_index, start=start_date, end=end_date, progress=False,
                                    auto_adjust=False, multi_level_index=False)

            # 재무 정보 가져오기
            ticker_info = yf.Ticker(symbol)
            info = ticker_info.info

            # 섹터, 산업 정보
            sector = info.get('sector', 'Unknown')
            industry = info.get('industry', 'Unknown')

            # 베타값 가져오기
            if 'beta' in info and info['beta'] is not None and not pd.isna(info['beta']):
                beta = float(info['beta'])
                beta = min(max(beta, -2.0), 4.0) # 이상치 방지
            else:
                # Yahoo Finance API에서 베타값을 찾을 수 없는 경우, 한국 종목은 네이버 금융 스크래핑 시도
                if symbol.endswith('.KS') or symbol.endswith('.KQ'): # 한국 주식인 경우
                    beta_from_naver = self.get_beta_from_naver_scraping(symbol)
                    if beta_from_naver is not None:
                        beta = beta_from_naver
                        beta = min(max(beta, -2.0), 4.0) # 이상치 방지
                    else:
                        beta = self.default_beta_values.get(symbol, 1.0)
                        print(f"{symbol}: 베타값 없음, 기본값 {beta} 사용")
                else:
                    beta = self.default_beta_values.get(symbol, 1.0)
                    print(f"{symbol}: 베타값 없음, 기본값 {beta} 사용")

            # PBR 값
            if symbol.endswith('.KS'): # 한국 종목
                pbr = self.get_pbr_from_naver_scraping(symbol)
                if pbr is None or pbr <= 0:
                    if 'priceToBook' in info and info['priceToBook'] is not None and not pd.isna(info['priceToBook']):
                        pbr = float(info['priceToBook'])
                    else:
                        pbr = 1.0
                        print(f"{symbol}: PBR 정보 없음, 기본값 1.0 사용")
            else: # 미국 종목
                if 'priceToBook' in info and info['priceToBook'] is not None and not pd.isna(info['priceToBook']):
                    pbr = float(info['priceToBook'])
                    print(f"{symbol}: Yahoo Finance에서 PBR값 {pbr:.4f} 가져옴")
                else:
                    pbr = 1.0
                    print(f"{symbol}: PBR 정보 없음, 기본값 1.0 사용")

            # 시가총액 처리
            if 'marketCap' in info and info['marketCap'] and not pd.isna(info['marketCap']):
                market_cap = info['marketCap']
                if symbol.endswith('.KS'): # 한국 종목의 경우 KRW를 USD로 변환
                    krw_to_usd = self.get_exchange_rate_krw_to_usd()
                    market_cap = market_cap * krw_to_usd
                    print(f"{symbol}: 시가총액 {info['marketCap']:,.0f} KRW → {market_cap:,.0f} USD로 변환")
                else:
                    print(f"{symbol}: 시가총액 {market_cap:,.0f} USD")
            else:
                market_cap = 1000000000 # 기본값: 10억 USD

            # 각 일별 날짜에 대한 지표 계산
            for target_date in daily_dates:
                # 해당일 또는 그 이전 가장 가까운 거래일 찾기
                available_dates = hist_data.index[hist_data.index <= pd.Timestamp(target_date)]
                if len(available_dates) == 0:
                    print(f"{symbol}: {target_date.strftime('%Y-%m-%d')}에 해당하는 데이터 없음")
                    continue

                closest_date = available_dates.max()
                date_str = closest_date.strftime('%Y-%m-%d')

                # 해당 날짜까지의 데이터 추출
                data_until_date = hist_data.loc[:closest_date]

                # 모멘텀 계산
                current_price = data_until_date['Adj Close'][-1]

                # 1개월 모멘텀
                one_month_ago = closest_date - relativedelta(months=1)
                one_month_prices = data_until_date[data_until_date.index <= one_month_ago]
                momentum_1m = ((current_price / one_month_prices['Adj Close'][-1]) - 1) * 100 if len(one_month_prices) > 0 else 0

                # 3개월 모멘텀
                three_months_ago = closest_date - relativedelta(months=3)
                three_month_prices = data_until_date[data_until_date.index <= three_months_ago]
                momentum_3m = ((current_price / three_month_prices['Adj Close'][-1]) - 1) * 100 if len(three_month_prices) > 0 else 0

                # 6개월 모멘텀
                six_months_ago = closest_date - relativedelta(months=6)
                six_month_prices = data_until_date[data_until_date.index <= six_months_ago]
                momentum_6m = ((current_price / six_month_prices['Adj Close'][-1]) - 1) * 100 if len(six_month_prices) > 0 else 0

                # 12개월 모멘텀
                twelve_months_ago = closest_date - relativedelta(months=12)
                twelve_month_prices = data_until_date[data_until_date.index <= twelve_months_ago]
                momentum_12m = ((current_price / twelve_month_prices['Adj Close'][-1]) - 1) * 100 if len(twelve_month_prices) > 0 else 0

                # 변동성 계산
                returns = data_until_date['Adj Close'].pct_change().dropna()
                volatility = returns.std() * np.sqrt(252) * 100 if len(returns) > 30 else 0 # 연간화, 퍼센트 변환

                # RSI 계산
                delta = data_until_date['Adj Close'].diff().dropna()
                up = delta.copy()
                up[up < 0] = 0
                down = -delta.copy()
                down[down < 0] = 0

                avg_gain = up.rolling(window=14).mean()
                avg_loss = down.rolling(window=14).mean()

                rs = avg_gain / avg_loss.replace(0, 0.001) # 0으로 나누기 방지
                rsi = 100 - (100 / (1 + rs))
                rsi_value = rsi.iloc[-1]

                # MACD 계산
                exp1 = data_until_date['Adj Close'].ewm(span=12, adjust=False).mean()
                exp2 = data_until_date['Adj Close'].ewm(span=26, adjust=False).mean()
                macd = exp1 - exp2
                signal = macd.ewm(span=9, adjust=False).mean()
                hist = macd - signal

                macd_value = macd.iloc[-1]
                signal_value = signal.iloc[-1]
                hist_value = hist.iloc[-1]

                # 결과 저장
                results.append({
                    'Symbol': symbol,
                    'Name': name,
                    'Date': date_str,
                    'Beta': round(beta, 2),
                    'PBR': round(pbr, 2),
                    'MarketCap': round(market_cap / 1_000_000_000, 2), # 10억 단위로 변환
                    'Momentum1M': round(momentum_1m, 2),
                    'Momentum3M': round(momentum_3m, 2),
                    'Momentum6M': round(momentum_6m, 2),
                    'Momentum12M': round(momentum_12m, 2),
                    'Volatility': round(volatility, 2),
                    'RSI': round(rsi_value, 2),
                    'MACD': round(macd_value, 2),
                    'Signal': round(signal_value, 2),
                    'MACD_Hist': round(hist_value, 2),
                    'Sector': sector,
                    'Industry': industry,
                    'Beta_Factor': 0,
                    'Value_Factor': 0,
                    'Size_Factor': 0,
                    'Momentum_Factor': 0,
                    'Volatility_Factor': 0,
                    'weighted_score': 0,
                    'factor_percentile': 0,
                    'smart_signal': 'NEUTRAL',
                    'signal_strength': 'MEDIUM',
                    'rebalance_priority': 0,
                    'to_rebalance': 0
                })

        except Exception as e:
            print(f"{symbol} 처리 중 오류 발생: {e}")

        return results

    def calculate_all_indicators(self):
        """모든 종목에 대한 일별 지표를 계산합니다"""
        all_results = []

        # 한국 주식 시장 일별 날짜 생성
        kr_dates = self.generate_daily_dates('KRX')

        # 미국 주식 시장 일별 날짜 생성
        us_dates = self.generate_daily_dates('NYSE')

        # 종목 목록 가져오기
        if not self.kr_stocks:
            self.get_korean_stocks()

        if not self.us_stocks:
            self.get_us_stocks()

        # 한국 주식 처리
        print("\n한국 주식 데이터 처리 중...")
        for idx, stock in enumerate(self.kr_stocks, 1):
            symbol = stock['symbol']
            name = stock['name']

            print(f"[{idx}/{len(self.kr_stocks)}] {name} ({symbol}) 처리 중...")
            results = self.calculate_indicators_for_stock(symbol, name, kr_dates, '^KS11')
            all_results.extend(results)

        # 미국 주식 처리
        print("\n미국 주식 데이터 처리 중...")
        for idx, stock in enumerate(self.us_stocks, 1):
            symbol = stock['symbol']
            name = stock['name']

            print(f"[{idx}/{len(self.us_stocks)}] {name} ({symbol}) 처리 중...")
            results = self.calculate_indicators_for_stock(symbol, name, us_dates, '^GSPC')
            all_results.extend(results)

        # 데이터프레임으로 변환
        self.factor_model_data = pd.DataFrame(all_results)

        return self.factor_model_data

    def calculate_factor_scores(self):
        """각 일별 날짜에 대한 팩터 점수를 계산합니다"""
        if len(self.factor_model_data) == 0:
            print("계산할 데이터가 없습니다")
            return

        print("\n팩터 점수 계산 중...")

        for date in self.factor_model_data['Date'].unique():
            date_df = self.factor_model_data[self.factor_model_data['Date'] == date].copy()

            if len(date_df) < 5: # 충분한 종목이 없으면 건너뜀
                print(f"{date} 날짜에 충분한 종목 데이터가 없어 팩터 점수 계산을 건너뜁니다")
                continue

            # 팩터 순위 계산 (퍼센타일로)
            date_df['Beta_Factor'] = -date_df['Beta'].rank(pct=True) # 베타가 낮을수록 좋음
            date_df['Value_Factor'] = -date_df['PBR'].rank(pct=True) # PBR이 낮을수록 좋음
            date_df['Size_Factor'] = -date_df['MarketCap'].rank(pct=True) # 소형주가 선호됨
            date_df['Momentum_Factor'] = date_df['Momentum12M'].rank(pct=True) # 모멘텀이 높을수록 좋음
            date_df['Volatility_Factor'] = -date_df['Volatility'].rank(pct=True) # 변동성이 낮을수록 좋음

            # 가중 점수 계산
            date_df['weighted_score'] = (
                date_df['Beta_Factor'] * self.factor_weights['Beta_Factor'] +
                date_df['Value_Factor'] * self.factor_weights['Value_Factor'] +
                date_df['Size_Factor'] * self.factor_weights['Size_Factor'] +
                date_df['Momentum_Factor'] * self.factor_weights['Momentum_Factor'] +
                date_df['Volatility_Factor'] * self.factor_weights['Volatility_Factor']
            )

            # 가중 점수의 퍼센타일 계산
            date_df['factor_percentile'] = date_df['weighted_score'].rank(pct=True)

            # 신호 생성
            date_df['smart_signal'] = 'NEUTRAL'
            date_df.loc[date_df['factor_percentile'] > 0.7, 'smart_signal'] = 'BUY'
            date_df.loc[date_df['factor_percentile'] < 0.3, 'smart_signal'] = 'SELL'

            # 신호 강도
            date_df['signal_strength'] = 'MEDIUM'
            date_df.loc[date_df['factor_percentile'] > 0.9, 'signal_strength'] = 'STRONG'
            date_df.loc[date_df['factor_percentile'] < 0.1, 'signal_strength'] = 'STRONG'

            # 리밸런싱 우선순위
            date_df['rebalance_priority'] = date_df['factor_percentile'].rank(ascending=False)

            # 리밸런싱 플래그
            date_df['to_rebalance'] = 0
            date_df.loc[date_df['smart_signal'] != 'NEUTRAL', 'to_rebalance'] = 1

            # 메인 데이터프레임 업데이트
            for index, row in date_df.iterrows():
                mask = (self.factor_model_data['Symbol'] == row['Symbol']) & (self.factor_model_data['Date'] == date)
                for col in ['Beta_Factor', 'Value_Factor', 'Size_Factor', 'Momentum_Factor',
                           'Volatility_Factor', 'weighted_score', 'factor_percentile',
                           'smart_signal', 'signal_strength', 'rebalance_priority', 'to_rebalance']:
                    self.factor_model_data.loc[mask, col] = row[col]

        print("팩터 점수 계산 완료")
        return self.factor_model_data

    def save_data(self):
        """계산된 데이터를 저장합니다"""
        if len(self.factor_model_data) == 0:
            print("저장할 데이터가 없습니다")
            return None

        # 날짜와 티커로 정렬
        self.factor_model_data = self.factor_model_data.sort_values(['Date', 'Symbol'])

        # 컬럼 순서 재정렬
        cols = ['Symbol', 'Name', 'Date', 'Beta', 'PBR', 'MarketCap',
               'Momentum1M', 'Momentum3M', 'Momentum6M', 'Momentum12M',
               'Volatility', 'RSI', 'MACD', 'Signal', 'MACD_Hist',
               'Sector', 'Industry', 'Beta_Factor', 'Value_Factor',
               'Size_Factor', 'Momentum_Factor', 'Volatility_Factor',
               'weighted_score', 'factor_percentile', 'smart_signal',
               'signal_strength', 'rebalance_priority', 'to_rebalance']

        self.factor_model_data = self.factor_model_data[cols]

        # CSV 저장
        date_str = self.current_date.strftime('%Y%m%d')
        output_file = f"processed_daily_5factor_model_{date_str}.csv"
        self.factor_model_data.to_csv(output_file, index=False)
        print(f"\n데이터가 {output_file}에 저장되었습니다")

        # 요약 정보 출력
        print(f"\n데이터 요약:")
        print(f"- 처리된 종목 수: {self.factor_model_data['Symbol'].nunique()}")
        print(f"- 처리된 일 수: {self.factor_model_data['Date'].nunique()}")
        print(f"- 총 행 수: {len(self.factor_model_data)}")

        # 매수/매도 신호 개수
        buy_count = len(self.factor_model_data[self.factor_model_data['smart_signal'] == 'BUY'])
        sell_count = len(self.factor_model_data[self.factor_model_data['smart_signal'] == 'SELL'])
        print(f"- 매수 신호 수: {buy_count}")
        print(f"- 매도 신호 수: {sell_count}")

        return output_file

    def run_pipeline(self):
        """전체 데이터 파이프라인을 실행합니다"""
        print(f"시작 시간: {self.current_date.strftime('%Y-%m-%d %H:%M:%S')}")

        # 주식 목록 가져오기
        self.get_korean_stocks()
        self.get_us_stocks()

        # 일별 지표 계산
        self.calculate_all_indicators()

        # 팩터 점수 계산
        self.calculate_factor_scores()

        # 데이터 저장
        self.save_data()

        # 총 실행 시간 출력
        elapsed_time = time.time() - self.start_time
        print(f"\n전체 처리 완료! 총 실행 시간: {elapsed_time:.2f}초")

        return self.factor_model_data

# 실행 코드
if __name__ == "__main__":
    model = DailyStockFactorModel()
    result = model.run_pipeline()
# Out:
# GPU 라이브러리 로드 성공 - GPU 가속 사용 가능
# 일별 5팩터 모델 데이터 처리 시작
# 시작 시간: 2025-06-04 13:02:58
#
# 한국 대표 주식 가져오기...
# 한국 주식 29개 로드 완료
#
# 미국 대표 주식 가져오기...
# 미국 주식 17개 로드 완료
# KRX 시장의 지난 1년간 거래일 242개 찾음
# NYSE 시장의 지난 1년간 거래일 251개 찾음
#
# 한국 주식 데이터 처리 중...
# [1/29] AJ네트웍스 (095570.KS) 처리 중...
# 095570.KS: 네이버 금융에서 PBR값 0.4100 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 095570.KS: 시가총액 179,227,754,496 KRW → 130,207,307 USD로 변환
# [2/29] AK홀딩스 (006840.KS) 처리 중...
# 006840.KS: 네이버 금융에서 PBR값 0.2900 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 006840.KS: 시가총액 156,285,091,840 KRW → 113,539,675 USD로 변환
# [3/29] BGF (027410.KS) 처리 중...
# 027410.KS: 네이버 금융에서 PBR값 0.2400 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 027410.KS: 시가총액 417,768,898,560 KRW → 303,505,244 USD로 변환
# [4/29] BGF리테일 (282330.KS) 처리 중...
# 282330.KS: 네이버 금융에서 PBR값 1.6800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 282330.KS: 시가총액 1,891,612,491,776 KRW → 1,374,238,995 USD로 변환
# [5/29] BNK금융지주 (138930.KS) 처리 중...
# 138930.KS: 네이버 금융에서 PBR값 0.3300 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 138930.KS: 시가총액 3,562,717,052,928 KRW → 2,588,281,016 USD로 변환
# [6/29] BYC (001460.KS) 처리 중...
# 001460.KS: 네이버 금융에서 PBR값 0.5800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 001460.KS: 시가총액 273,389,502,464 KRW → 198,614,947 USD로 변환
# [7/29] BYC우 (001465.KS) 처리 중...
# 001465.KS: 네이버 금융에서 PBR값 0.2500 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 001465.KS: 시가총액 272,097,460,224 KRW → 197,676,290 USD로 변환
# [8/29] CJ (001040.KS) 처리 중...
# 001040.KS: 네이버 금융에서 PBR값 0.9400 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 001040.KS: 시가총액 4,110,186,184,704 KRW → 2,986,012,281 USD로 변환
# [9/29] CJ CGV (079160.KS) 처리 중...
# 079160.KS: 네이버 금융에서 PBR값 1.2400 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 079160.KS: 시가총액 813,825,720,320 KRW → 591,236,865 USD로 변환
# [10/29] CJ4우(전환) (00104K.KS) 처리 중...
# 00104K.KS: 네이버 금융에서 PBR값 0.7600 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 00104K.KS: 시가총액 4,028,439,724,032 KRW → 2,926,624,233 USD로 변환
# [11/29] CJ대한통운 (000120.KS) 처리 중...
# 000120.KS: 네이버 금융에서 PBR값 0.4200 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 000120.KS: 시가총액 1,665,415,905,280 KRW → 1,209,909,265 USD로 변환
# [12/29] CJ씨푸드 (011150.KS) 처리 중...
# 011150.KS: 네이버 금융에서 PBR값 1.3100 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 011150.KS: 시가총액 109,050,585,088 KRW → 79,224,242 USD로 변환
# [13/29] CJ씨푸드1우 (011155.KS) 처리 중...
# 011155.KS: 네이버 금융에서 PBR값 7.8200 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 011155.KS: 시가총액 111,388,131,328 KRW → 80,922,448 USD로 변환
# [14/29] CJ우 (001045.KS) 처리 중...
# 001045.KS: 네이버 금융에서 PBR값 0.5400 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 001045.KS: 시가총액 4,073,406,070,784 KRW → 2,959,291,868 USD로 변환
# [15/29] CJ제일제당 (097950.KS) 처리 중...
# 097950.KS: 네이버 금융에서 PBR값 0.4800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 097950.KS: 시가총액 3,475,816,841,216 KRW → 2,525,148,815 USD로 변환
# [16/29] CJ제일제당 우 (097955.KS) 처리 중...
# 097955.KS: 네이버 금융에서 PBR값 0.2900 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 097955.KS: 시가총액 3,459,076,849,664 KRW → 2,512,987,366 USD로 변환
# [17/29] CR홀딩스 (000480.KS) 처리 중...
# 000480.KS: 네이버 금융에서 PBR값 0.3800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 000480.KS: 시가총액 223,610,765,312 KRW → 162,451,155 USD로 변환
# [18/29] CS홀딩스 (000590.KS) 처리 중...
# 000590.KS: 네이버 금융에서 PBR값 0.2800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 000590.KS: 시가총액 88,857,067,520 KRW → 64,553,838 USD로 변환
# [19/29] DB (012030.KS) 처리 중...
# 012030.KS: 네이버 금융에서 PBR값 0.6800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 012030.KS: 시가총액 282,916,913,152 KRW → 205,536,523 USD로 변환
# [20/29] DB손해보험 (005830.KS) 처리 중...
# 005830.KS: 베타값 없음, 기본값 1.0 사용
# 005830.KS: 네이버 금융에서 PBR값 0.6700 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 005830.KS: 시가총액 6,226,510,872,576 KRW → 4,523,502,610 USD로 변환
# [21/29] DB증권 (016610.KS) 처리 중...
# 016610.KS: 네이버 금융에서 PBR값 0.3100 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 016610.KS: 시가총액 315,011,858,432 KRW → 228,853,204 USD로 변환
# [22/29] DB하이텍 (000990.KS) 처리 중...
# 000990.KS: 네이버 금융에서 PBR값 0.9100 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 000990.KS: 시가총액 1,769,019,408,384 KRW → 1,285,176,253 USD로 변환
# [23/29] DH오토넥스 (000300.KS) 처리 중...
# 000300.KS: 베타값 없음, 기본값 1.0 사용
# 000300.KS: 네이버 금융에서 PBR값 4.3200 가져옴
# [24/29] DI동일 (001530.KS) 처리 중...
# 001530.KS: 네이버 금융에서 PBR값 1.2600 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 001530.KS: 시가총액 668,535,095,296 KRW → 485,684,569 USD로 변환
# [25/29] DKME (015590.KS) 처리 중...
# 015590.KS: 네이버 금융에서 PBR값 0.9400 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 015590.KS: 시가총액 122,045,726,720 KRW → 88,665,093 USD로 변환
# [26/29] DL (000210.KS) 처리 중...
# 000210.KS: 네이버 금융에서 PBR값 0.2800 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 000210.KS: 시가총액 1,087,121,391,616 KRW → 789,783,645 USD로 변환
# [27/29] DL우 (000215.KS) 처리 중...
# 000215.KS: 네이버 금융에서 PBR값 0.1300 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 000215.KS: 시가총액 1,029,499,191,296 KRW → 747,921,649 USD로 변환
# [28/29] DL이앤씨 (375500.KS) 처리 중...
# 375500.KS: 네이버 금융에서 PBR값 0.4300 가져옴
# 현재 환율: 1 USD = 1376.48 KRW, 1 KRW = 0.00072649 USD
# 375500.KS: 시가총액 1,945,917,587,456 KRW → 1,413,691,145 USD로 변환
# [29/29] DL이앤씨2우(전환) (37550L.KS) 처리 중...
# 37550L.KS: 네이버 금융에서 PBR값 0.2800 가져옴
#
# 미국 주식 데이터 처리 중...
# [1/17] Agilent Technologies Inc. Common Stock (A) 처리 중...
# A: Yahoo Finance에서 PBR값 5.2177 가져옴
# A: 시가총액 32,031,168,512 USD
# [2/17] Alcoa Corporation Common Stock  (AA) 처리 중...
# AA: Yahoo Finance에서 PBR값 1.2315 가져옴
# AA: 시가총액 7,161,229,312 USD
# [3/17] Artius II Acquisition Inc. Class A Ordinary Shares (AACB) 처리 중...
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AACBR']: YFInvalidPeriodError("AACBR: Period 'max' is invalid, must be of the format 1d, 5d, etc.")
# AACB: 베타값 없음, 기본값 1.0 사용
# AACB: Yahoo Finance에서 PBR값 -23.3025 가져옴
# AACB: 시가총액 296,646,016 USD
# AACB: 2024-06-04에 해당하는 데이터 없음
# AACB: 2024-06-05에 해당하는 데이터 없음
# AACB: 2024-06-06에 해당하는 데이터 없음
# AACB: 2024-06-07에 해당하는 데이터 없음
# AACB: 2024-06-10에 해당하는 데이터 없음
# AACB: 2024-06-11에 해당하는 데이터 없음
# AACB: 2024-06-12에 해당하는 데이터 없음
# AACB: 2024-06-13에 해당하는 데이터 없음
# AACB: 2024-06-14에 해당하는 데이터 없음
# AACB: 2024-06-17에 해당하는 데이터 없음
# AACB: 2024-06-18에 해당하는 데이터 없음
# AACB: 2024-06-20에 해당하는 데이터 없음
# AACB: 2024-06-21에 해당하는 데이터 없음
# AACB: 2024-06-24에 해당하는 데이터 없음
# AACB: 2024-06-25에 해당하는 데이터 없음
# AACB: 2024-06-26에 해당하는 데이터 없음
# AACB: 2024-06-27에 해당하는 데이터 없음
# AACB: 2024-06-28에 해당하는 데이터 없음
# AACB: 2024-07-01에 해당하는 데이터 없음
# AACB: 2024-07-02에 해당하는 데이터 없음
# AACB: 2024-07-03에 해당하는 데이터 없음
# AACB: 2024-07-05에 해당하는 데이터 없음
# AACB: 2024-07-08에 해당하는 데이터 없음
# AACB: 2024-07-09에 해당하는 데이터 없음
# AACB: 2024-07-10에 해당하는 데이터 없음
# AACB: 2024-07-11에 해당하는 데이터 없음
# AACB: 2024-07-12에 해당하는 데이터 없음
# AACB: 2024-07-15에 해당하는 데이터 없음
# AACB: 2024-07-16에 해당하는 데이터 없음
# AACB: 2024-07-17에 해당하는 데이터 없음
# AACB: 2024-07-18에 해당하는 데이터 없음
# AACB: 2024-07-19에 해당하는 데이터 없음
# AACB: 2024-07-22에 해당하는 데이터 없음
# AACB: 2024-07-23에 해당하는 데이터 없음
# AACB: 2024-07-24에 해당하는 데이터 없음
# AACB: 2024-07-25에 해당하는 데이터 없음
# AACB: 2024-07-26에 해당하는 데이터 없음
# AACB: 2024-07-29에 해당하는 데이터 없음
# AACB: 2024-07-30에 해당하는 데이터 없음
# AACB: 2024-07-31에 해당하는 데이터 없음
# AACB: 2024-08-01에 해당하는 데이터 없음
# AACB: 2024-08-02에 해당하는 데이터 없음
# AACB: 2024-08-05에 해당하는 데이터 없음
# AACB: 2024-08-06에 해당하는 데이터 없음
# AACB: 2024-08-07에 해당하는 데이터 없음
# AACB: 2024-08-08에 해당하는 데이터 없음
# AACB: 2024-08-09에 해당하는 데이터 없음
# AACB: 2024-08-12에 해당하는 데이터 없음
# AACB: 2024-08-13에 해당하는 데이터 없음
# AACB: 2024-08-14에 해당하는 데이터 없음
# AACB: 2024-08-15에 해당하는 데이터 없음
# AACB: 2024-08-16에 해당하는 데이터 없음
# AACB: 2024-08-19에 해당하는 데이터 없음
# AACB: 2024-08-20에 해당하는 데이터 없음
# AACB: 2024-08-21에 해당하는 데이터 없음
# AACB: 2024-08-22에 해당하는 데이터 없음
# AACB: 2024-08-23에 해당하는 데이터 없음
# AACB: 2024-08-26에 해당하는 데이터 없음
# AACB: 2024-08-27에 해당하는 데이터 없음
# AACB: 2024-08-28에 해당하는 데이터 없음
# AACB: 2024-08-29에 해당하는 데이터 없음
# AACB: 2024-08-30에 해당하는 데이터 없음
# AACB: 2024-09-03에 해당하는 데이터 없음
# AACB: 2024-09-04에 해당하는 데이터 없음
# AACB: 2024-09-05에 해당하는 데이터 없음
# AACB: 2024-09-06에 해당하는 데이터 없음
# AACB: 2024-09-09에 해당하는 데이터 없음
# AACB: 2024-09-10에 해당하는 데이터 없음
# AACB: 2024-09-11에 해당하는 데이터 없음
# AACB: 2024-09-12에 해당하는 데이터 없음
# AACB: 2024-09-13에 해당하는 데이터 없음
# AACB: 2024-09-16에 해당하는 데이터 없음
# AACB: 2024-09-17에 해당하는 데이터 없음
# AACB: 2024-09-18에 해당하는 데이터 없음
# AACB: 2024-09-19에 해당하는 데이터 없음
# AACB: 2024-09-20에 해당하는 데이터 없음
# AACB: 2024-09-23에 해당하는 데이터 없음
# AACB: 2024-09-24에 해당하는 데이터 없음
# AACB: 2024-09-25에 해당하는 데이터 없음
# AACB: 2024-09-26에 해당하는 데이터 없음
# AACB: 2024-09-27에 해당하는 데이터 없음
# AACB: 2024-09-30에 해당하는 데이터 없음
# AACB: 2024-10-01에 해당하는 데이터 없음
# AACB: 2024-10-02에 해당하는 데이터 없음
# AACB: 2024-10-03에 해당하는 데이터 없음
# AACB: 2024-10-04에 해당하는 데이터 없음
# AACB: 2024-10-07에 해당하는 데이터 없음
# AACB: 2024-10-08에 해당하는 데이터 없음
# AACB: 2024-10-09에 해당하는 데이터 없음
# AACB: 2024-10-10에 해당하는 데이터 없음
# AACB: 2024-10-11에 해당하는 데이터 없음
# AACB: 2024-10-14에 해당하는 데이터 없음
# AACB: 2024-10-15에 해당하는 데이터 없음
# AACB: 2024-10-16에 해당하는 데이터 없음
# AACB: 2024-10-17에 해당하는 데이터 없음
# AACB: 2024-10-18에 해당하는 데이터 없음
# AACB: 2024-10-21에 해당하는 데이터 없음
# AACB: 2024-10-22에 해당하는 데이터 없음
# AACB: 2024-10-23에 해당하는 데이터 없음
# AACB: 2024-10-24에 해당하는 데이터 없음
# AACB: 2024-10-25에 해당하는 데이터 없음
# AACB: 2024-10-28에 해당하는 데이터 없음
# AACB: 2024-10-29에 해당하는 데이터 없음
# AACB: 2024-10-30에 해당하는 데이터 없음
# AACB: 2024-10-31에 해당하는 데이터 없음
# AACB: 2024-11-01에 해당하는 데이터 없음
# AACB: 2024-11-04에 해당하는 데이터 없음
# AACB: 2024-11-05에 해당하는 데이터 없음
# AACB: 2024-11-06에 해당하는 데이터 없음
# AACB: 2024-11-07에 해당하는 데이터 없음
# AACB: 2024-11-08에 해당하는 데이터 없음
# AACB: 2024-11-11에 해당하는 데이터 없음
# AACB: 2024-11-12에 해당하는 데이터 없음
# AACB: 2024-11-13에 해당하는 데이터 없음
# AACB: 2024-11-14에 해당하는 데이터 없음
# AACB: 2024-11-15에 해당하는 데이터 없음
# AACB: 2024-11-18에 해당하는 데이터 없음
# AACB: 2024-11-19에 해당하는 데이터 없음
# AACB: 2024-11-20에 해당하는 데이터 없음
# AACB: 2024-11-21에 해당하는 데이터 없음
# AACB: 2024-11-22에 해당하는 데이터 없음
# AACB: 2024-11-25에 해당하는 데이터 없음
# AACB: 2024-11-26에 해당하는 데이터 없음
# AACB: 2024-11-27에 해당하는 데이터 없음
# AACB: 2024-11-29에 해당하는 데이터 없음
# AACB: 2024-12-02에 해당하는 데이터 없음
# AACB: 2024-12-03에 해당하는 데이터 없음
# AACB: 2024-12-04에 해당하는 데이터 없음
# AACB: 2024-12-05에 해당하는 데이터 없음
# AACB: 2024-12-06에 해당하는 데이터 없음
# AACB: 2024-12-09에 해당하는 데이터 없음
# AACB: 2024-12-10에 해당하는 데이터 없음
# AACB: 2024-12-11에 해당하는 데이터 없음
# AACB: 2024-12-12에 해당하는 데이터 없음
# AACB: 2024-12-13에 해당하는 데이터 없음
# AACB: 2024-12-16에 해당하는 데이터 없음
# AACB: 2024-12-17에 해당하는 데이터 없음
# AACB: 2024-12-18에 해당하는 데이터 없음
# AACB: 2024-12-19에 해당하는 데이터 없음
# AACB: 2024-12-20에 해당하는 데이터 없음
# AACB: 2024-12-23에 해당하는 데이터 없음
# AACB: 2024-12-24에 해당하는 데이터 없음
# AACB: 2024-12-26에 해당하는 데이터 없음
# AACB: 2024-12-27에 해당하는 데이터 없음
# AACB: 2024-12-30에 해당하는 데이터 없음
# AACB: 2024-12-31에 해당하는 데이터 없음
# AACB: 2025-01-02에 해당하는 데이터 없음
# AACB: 2025-01-03에 해당하는 데이터 없음
# AACB: 2025-01-06에 해당하는 데이터 없음
# AACB: 2025-01-07에 해당하는 데이터 없음
# AACB: 2025-01-08에 해당하는 데이터 없음
# AACB: 2025-01-10에 해당하는 데이터 없음
# AACB: 2025-01-13에 해당하는 데이터 없음
# AACB: 2025-01-14에 해당하는 데이터 없음
# AACB: 2025-01-15에 해당하는 데이터 없음
# AACB: 2025-01-16에 해당하는 데이터 없음
# AACB: 2025-01-17에 해당하는 데이터 없음
# AACB: 2025-01-21에 해당하는 데이터 없음
# AACB: 2025-01-22에 해당하는 데이터 없음
# AACB: 2025-01-23에 해당하는 데이터 없음
# AACB: 2025-01-24에 해당하는 데이터 없음
# AACB: 2025-01-27에 해당하는 데이터 없음
# AACB: 2025-01-28에 해당하는 데이터 없음
# AACB: 2025-01-29에 해당하는 데이터 없음
# AACB: 2025-01-30에 해당하는 데이터 없음
# AACB: 2025-01-31에 해당하는 데이터 없음
# AACB: 2025-02-03에 해당하는 데이터 없음
# AACB: 2025-02-04에 해당하는 데이터 없음
# AACB: 2025-02-05에 해당하는 데이터 없음
# AACB: 2025-02-06에 해당하는 데이터 없음
# AACB: 2025-02-07에 해당하는 데이터 없음
# AACB: 2025-02-10에 해당하는 데이터 없음
# AACB: 2025-02-11에 해당하는 데이터 없음
# AACB: 2025-02-12에 해당하는 데이터 없음
# AACB: 2025-02-13에 해당하는 데이터 없음
# AACB: 2025-02-14에 해당하는 데이터 없음
# AACB: 2025-02-18에 해당하는 데이터 없음
# AACB: 2025-02-19에 해당하는 데이터 없음
# AACB: 2025-02-20에 해당하는 데이터 없음
# AACB: 2025-02-21에 해당하는 데이터 없음
# AACB: 2025-02-24에 해당하는 데이터 없음
# AACB: 2025-02-25에 해당하는 데이터 없음
# AACB: 2025-02-26에 해당하는 데이터 없음
# AACB: 2025-02-27에 해당하는 데이터 없음
# AACB: 2025-02-28에 해당하는 데이터 없음
# AACB: 2025-03-03에 해당하는 데이터 없음
# AACB: 2025-03-04에 해당하는 데이터 없음
# AACB: 2025-03-05에 해당하는 데이터 없음
# AACB: 2025-03-06에 해당하는 데이터 없음
# AACB: 2025-03-07에 해당하는 데이터 없음
# AACB: 2025-03-10에 해당하는 데이터 없음
# AACB: 2025-03-11에 해당하는 데이터 없음
# AACB: 2025-03-12에 해당하는 데이터 없음
# AACB: 2025-03-13에 해당하는 데이터 없음
# AACB: 2025-03-14에 해당하는 데이터 없음
# AACB: 2025-03-17에 해당하는 데이터 없음
# AACB: 2025-03-18에 해당하는 데이터 없음
# AACB: 2025-03-19에 해당하는 데이터 없음
# AACB: 2025-03-20에 해당하는 데이터 없음
# AACB: 2025-03-21에 해당하는 데이터 없음
# AACB: 2025-03-24에 해당하는 데이터 없음
# AACB: 2025-03-25에 해당하는 데이터 없음
# AACB: 2025-03-26에 해당하는 데이터 없음
# AACB: 2025-03-27에 해당하는 데이터 없음
# AACB: 2025-03-28에 해당하는 데이터 없음
# AACB: 2025-03-31에 해당하는 데이터 없음
# AACB: 2025-04-01에 해당하는 데이터 없음
# AACB: 2025-04-02에 해당하는 데이터 없음
# AACB: 2025-04-03에 해당하는 데이터 없음
# AACB: 2025-04-04에 해당하는 데이터 없음
# AACB 처리 중 오류 발생: single positional indexer is out-of-bounds
# [4/17] Artius II Acquisition Inc. Rights (AACBR) 처리 중...
# AACBR: 데이터가 충분하지 않습니다 (행 수: 0)
# [5/17] Artius II Acquisition Inc. Units (AACBU) 처리 중...
# AACBU: 베타값 없음, 기본값 1.0 사용
# AACBU: Yahoo Finance에서 PBR값 -23.8106 가져옴
# AACBU: 시가총액 259,554,256 USD
# AACBU: 2024-06-04에 해당하는 데이터 없음
# AACBU: 2024-06-05에 해당하는 데이터 없음
# AACBU: 2024-06-06에 해당하는 데이터 없음
# AACBU: 2024-06-07에 해당하는 데이터 없음
# AACBU: 2024-06-10에 해당하는 데이터 없음
# AACBU: 2024-06-11에 해당하는 데이터 없음
# AACBU: 2024-06-12에 해당하는 데이터 없음
# AACBU: 2024-06-13에 해당하는 데이터 없음
# AACBU: 2024-06-14에 해당하는 데이터 없음
# AACBU: 2024-06-17에 해당하는 데이터 없음
# AACBU: 2024-06-18에 해당하는 데이터 없음
# AACBU: 2024-06-20에 해당하는 데이터 없음
# AACBU: 2024-06-21에 해당하는 데이터 없음
# AACBU: 2024-06-24에 해당하는 데이터 없음
# AACBU: 2024-06-25에 해당하는 데이터 없음
# AACBU: 2024-06-26에 해당하는 데이터 없음
# AACBU: 2024-06-27에 해당하는 데이터 없음
# AACBU: 2024-06-28에 해당하는 데이터 없음
# AACBU: 2024-07-01에 해당하는 데이터 없음
# AACBU: 2024-07-02에 해당하는 데이터 없음
# AACBU: 2024-07-03에 해당하는 데이터 없음
# AACBU: 2024-07-05에 해당하는 데이터 없음
# AACBU: 2024-07-08에 해당하는 데이터 없음
# AACBU: 2024-07-09에 해당하는 데이터 없음
# AACBU: 2024-07-10에 해당하는 데이터 없음
# AACBU: 2024-07-11에 해당하는 데이터 없음
# AACBU: 2024-07-12에 해당하는 데이터 없음
# AACBU: 2024-07-15에 해당하는 데이터 없음
# AACBU: 2024-07-16에 해당하는 데이터 없음
# AACBU: 2024-07-17에 해당하는 데이터 없음
# AACBU: 2024-07-18에 해당하는 데이터 없음
# AACBU: 2024-07-19에 해당하는 데이터 없음
# AACBU: 2024-07-22에 해당하는 데이터 없음
# AACBU: 2024-07-23에 해당하는 데이터 없음
# AACBU: 2024-07-24에 해당하는 데이터 없음
# AACBU: 2024-07-25에 해당하는 데이터 없음
# AACBU: 2024-07-26에 해당하는 데이터 없음
# AACBU: 2024-07-29에 해당하는 데이터 없음
# AACBU: 2024-07-30에 해당하는 데이터 없음
# AACBU: 2024-07-31에 해당하는 데이터 없음
# AACBU: 2024-08-01에 해당하는 데이터 없음
# AACBU: 2024-08-02에 해당하는 데이터 없음
# AACBU: 2024-08-05에 해당하는 데이터 없음
# AACBU: 2024-08-06에 해당하는 데이터 없음
# AACBU: 2024-08-07에 해당하는 데이터 없음
# AACBU: 2024-08-08에 해당하는 데이터 없음
# AACBU: 2024-08-09에 해당하는 데이터 없음
# AACBU: 2024-08-12에 해당하는 데이터 없음
# AACBU: 2024-08-13에 해당하는 데이터 없음
# AACBU: 2024-08-14에 해당하는 데이터 없음
# AACBU: 2024-08-15에 해당하는 데이터 없음
# AACBU: 2024-08-16에 해당하는 데이터 없음
# AACBU: 2024-08-19에 해당하는 데이터 없음
# AACBU: 2024-08-20에 해당하는 데이터 없음
# AACBU: 2024-08-21에 해당하는 데이터 없음
# AACBU: 2024-08-22에 해당하는 데이터 없음
# AACBU: 2024-08-23에 해당하는 데이터 없음
# AACBU: 2024-08-26에 해당하는 데이터 없음
# AACBU: 2024-08-27에 해당하는 데이터 없음
# AACBU: 2024-08-28에 해당하는 데이터 없음
# AACBU: 2024-08-29에 해당하는 데이터 없음
# AACBU: 2024-08-30에 해당하는 데이터 없음
# AACBU: 2024-09-03에 해당하는 데이터 없음
# AACBU: 2024-09-04에 해당하는 데이터 없음
# AACBU: 2024-09-05에 해당하는 데이터 없음
# AACBU: 2024-09-06에 해당하는 데이터 없음
# AACBU: 2024-09-09에 해당하는 데이터 없음
# AACBU: 2024-09-10에 해당하는 데이터 없음
# AACBU: 2024-09-11에 해당하는 데이터 없음
# AACBU: 2024-09-12에 해당하는 데이터 없음
# AACBU: 2024-09-13에 해당하는 데이터 없음
# AACBU: 2024-09-16에 해당하는 데이터 없음
# AACBU: 2024-09-17에 해당하는 데이터 없음
# AACBU: 2024-09-18에 해당하는 데이터 없음
# AACBU: 2024-09-19에 해당하는 데이터 없음
# AACBU: 2024-09-20에 해당하는 데이터 없음
# AACBU: 2024-09-23에 해당하는 데이터 없음
# AACBU: 2024-09-24에 해당하는 데이터 없음
# AACBU: 2024-09-25에 해당하는 데이터 없음
# AACBU: 2024-09-26에 해당하는 데이터 없음
# AACBU: 2024-09-27에 해당하는 데이터 없음
# AACBU: 2024-09-30에 해당하는 데이터 없음
# AACBU: 2024-10-01에 해당하는 데이터 없음
# AACBU: 2024-10-02에 해당하는 데이터 없음
# AACBU: 2024-10-03에 해당하는 데이터 없음
# AACBU: 2024-10-04에 해당하는 데이터 없음
# AACBU: 2024-10-07에 해당하는 데이터 없음
# AACBU: 2024-10-08에 해당하는 데이터 없음
# AACBU: 2024-10-09에 해당하는 데이터 없음
# AACBU: 2024-10-10에 해당하는 데이터 없음
# AACBU: 2024-10-11에 해당하는 데이터 없음
# AACBU: 2024-10-14에 해당하는 데이터 없음
# AACBU: 2024-10-15에 해당하는 데이터 없음
# AACBU: 2024-10-16에 해당하는 데이터 없음
# AACBU: 2024-10-17에 해당하는 데이터 없음
# AACBU: 2024-10-18에 해당하는 데이터 없음
# AACBU: 2024-10-21에 해당하는 데이터 없음
# AACBU: 2024-10-22에 해당하는 데이터 없음
# AACBU: 2024-10-23에 해당하는 데이터 없음
# AACBU: 2024-10-24에 해당하는 데이터 없음
# AACBU: 2024-10-25에 해당하는 데이터 없음
# AACBU: 2024-10-28에 해당하는 데이터 없음
# AACBU: 2024-10-29에 해당하는 데이터 없음
# AACBU: 2024-10-30에 해당하는 데이터 없음
# AACBU: 2024-10-31에 해당하는 데이터 없음
# AACBU: 2024-11-01에 해당하는 데이터 없음
# AACBU: 2024-11-04에 해당하는 데이터 없음
# AACBU: 2024-11-05에 해당하는 데이터 없음
# AACBU: 2024-11-06에 해당하는 데이터 없음
# AACBU: 2024-11-07에 해당하는 데이터 없음
# AACBU: 2024-11-08에 해당하는 데이터 없음
# AACBU: 2024-11-11에 해당하는 데이터 없음
# AACBU: 2024-11-12에 해당하는 데이터 없음
# AACBU: 2024-11-13에 해당하는 데이터 없음
# AACBU: 2024-11-14에 해당하는 데이터 없음
# AACBU: 2024-11-15에 해당하는 데이터 없음
# AACBU: 2024-11-18에 해당하는 데이터 없음
# AACBU: 2024-11-19에 해당하는 데이터 없음
# AACBU: 2024-11-20에 해당하는 데이터 없음
# AACBU: 2024-11-21에 해당하는 데이터 없음
# AACBU: 2024-11-22에 해당하는 데이터 없음
# AACBU: 2024-11-25에 해당하는 데이터 없음
# AACBU: 2024-11-26에 해당하는 데이터 없음
# AACBU: 2024-11-27에 해당하는 데이터 없음
# AACBU: 2024-11-29에 해당하는 데이터 없음
# AACBU: 2024-12-02에 해당하는 데이터 없음
# AACBU: 2024-12-03에 해당하는 데이터 없음
# AACBU: 2024-12-04에 해당하는 데이터 없음
# AACBU: 2024-12-05에 해당하는 데이터 없음
# AACBU: 2024-12-06에 해당하는 데이터 없음
# AACBU: 2024-12-09에 해당하는 데이터 없음
# AACBU: 2024-12-10에 해당하는 데이터 없음
# AACBU: 2024-12-11에 해당하는 데이터 없음
# AACBU: 2024-12-12에 해당하는 데이터 없음
# AACBU: 2024-12-13에 해당하는 데이터 없음
# AACBU: 2024-12-16에 해당하는 데이터 없음
# AACBU: 2024-12-17에 해당하는 데이터 없음
# AACBU: 2024-12-18에 해당하는 데이터 없음
# AACBU: 2024-12-19에 해당하는 데이터 없음
# AACBU: 2024-12-20에 해당하는 데이터 없음
# AACBU: 2024-12-23에 해당하는 데이터 없음
# AACBU: 2024-12-24에 해당하는 데이터 없음
# AACBU: 2024-12-26에 해당하는 데이터 없음
# AACBU: 2024-12-27에 해당하는 데이터 없음
# AACBU: 2024-12-30에 해당하는 데이터 없음
# AACBU: 2024-12-31에 해당하는 데이터 없음
# AACBU: 2025-01-02에 해당하는 데이터 없음
# AACBU: 2025-01-03에 해당하는 데이터 없음
# AACBU: 2025-01-06에 해당하는 데이터 없음
# AACBU: 2025-01-07에 해당하는 데이터 없음
# AACBU: 2025-01-08에 해당하는 데이터 없음
# AACBU: 2025-01-10에 해당하는 데이터 없음
# AACBU: 2025-01-13에 해당하는 데이터 없음
# AACBU: 2025-01-14에 해당하는 데이터 없음
# AACBU: 2025-01-15에 해당하는 데이터 없음
# AACBU: 2025-01-16에 해당하는 데이터 없음
# AACBU: 2025-01-17에 해당하는 데이터 없음
# AACBU: 2025-01-21에 해당하는 데이터 없음
# AACBU: 2025-01-22에 해당하는 데이터 없음
# AACBU: 2025-01-23에 해당하는 데이터 없음
# AACBU: 2025-01-24에 해당하는 데이터 없음
# AACBU: 2025-01-27에 해당하는 데이터 없음
# AACBU: 2025-01-28에 해당하는 데이터 없음
# AACBU: 2025-01-29에 해당하는 데이터 없음
# AACBU: 2025-01-30에 해당하는 데이터 없음
# AACBU: 2025-01-31에 해당하는 데이터 없음
# AACBU: 2025-02-03에 해당하는 데이터 없음
# AACBU: 2025-02-04에 해당하는 데이터 없음
# AACBU: 2025-02-05에 해당하는 데이터 없음
# AACBU: 2025-02-06에 해당하는 데이터 없음
# AACBU: 2025-02-07에 해당하는 데이터 없음
# AACBU: 2025-02-10에 해당하는 데이터 없음
# AACBU: 2025-02-11에 해당하는 데이터 없음
# AACBU: 2025-02-12에 해당하는 데이터 없음
# AACBU: 2025-02-13에 해당하는 데이터 없음
# AACBU: 2025-02-14에 해당하는 데이터 없음
# AACBU: 2025-02-18에 해당하는 데이터 없음
# AACBU: 2025-02-19에 해당하는 데이터 없음
# AACBU: 2025-02-20에 해당하는 데이터 없음
# AACBU: 2025-02-21에 해당하는 데이터 없음
# AACBU: 2025-02-24에 해당하는 데이터 없음
# AACBU: 2025-02-25에 해당하는 데이터 없음
# AACBU: 2025-02-26에 해당하는 데이터 없음
# AACBU: 2025-02-27에 해당하는 데이터 없음
# AACBU: 2025-02-28에 해당하는 데이터 없음
# AACBU: 2025-03-03에 해당하는 데이터 없음
# AACBU: 2025-03-04에 해당하는 데이터 없음
# AACBU: 2025-03-05에 해당하는 데이터 없음
# AACBU: 2025-03-06에 해당하는 데이터 없음
# AACBU: 2025-03-07에 해당하는 데이터 없음
# AACBU 처리 중 오류 발생: single positional indexer is out-of-bounds
# [6/17] ATA Creativity Global American Depositary Shares (AACG) 처리 중...
# AACG: Yahoo Finance에서 PBR값 0.4135 가져옴
# AACG: 시가총액 27,355,192 USD
# [7/17] Armada Acquisition Corp. II Units (AACIU) 처리 중...
# AACIU: 데이터가 충분하지 않습니다 (행 수: 9)
# [8/17] Ares Acquisition Corporation II Class A Ordinary Shares (AACT) 처리 중...
# AACT: 베타값 없음, 기본값 1.0 사용
# AACT: Yahoo Finance에서 PBR값 -5.8182 가져옴
# AACT: 시가총액 712,623,744 USD
# [9/17] American Airlines Group Inc. Common Stock (AAL) 처리 중...
# AAL: Yahoo Finance에서 PBR값 -1.6779 가져옴
# AAL: 시가총액 7,564,602,880 USD
# [10/17] AA Mission Acquisition Corp. Class A Ordinary Shares (AAM) 처리 중...
# AAM: 베타값 없음, 기본값 1.0 사용
# AAM: Yahoo Finance에서 PBR값 1.3111 가져옴
# AAM: 시가총액 456,450,112 USD
# AAM: 2024-06-04에 해당하는 데이터 없음
# AAM: 2024-06-05에 해당하는 데이터 없음
# AAM: 2024-06-06에 해당하는 데이터 없음
# AAM: 2024-06-07에 해당하는 데이터 없음
# AAM: 2024-06-10에 해당하는 데이터 없음
# AAM: 2024-06-11에 해당하는 데이터 없음
# AAM: 2024-06-12에 해당하는 데이터 없음
# AAM: 2024-06-13에 해당하는 데이터 없음
# AAM: 2024-06-14에 해당하는 데이터 없음
# AAM: 2024-06-17에 해당하는 데이터 없음
# AAM: 2024-06-18에 해당하는 데이터 없음
# AAM: 2024-06-20에 해당하는 데이터 없음
# AAM: 2024-06-21에 해당하는 데이터 없음
# AAM: 2024-06-24에 해당하는 데이터 없음
# AAM: 2024-06-25에 해당하는 데이터 없음
# AAM: 2024-06-26에 해당하는 데이터 없음
# AAM: 2024-06-27에 해당하는 데이터 없음
# AAM: 2024-06-28에 해당하는 데이터 없음
# AAM: 2024-07-01에 해당하는 데이터 없음
# AAM: 2024-07-02에 해당하는 데이터 없음
# AAM: 2024-07-03에 해당하는 데이터 없음
# AAM: 2024-07-05에 해당하는 데이터 없음
# AAM: 2024-07-08에 해당하는 데이터 없음
# AAM: 2024-07-09에 해당하는 데이터 없음
# AAM: 2024-07-10에 해당하는 데이터 없음
# AAM: 2024-07-11에 해당하는 데이터 없음
# AAM: 2024-07-12에 해당하는 데이터 없음
# AAM: 2024-07-15에 해당하는 데이터 없음
# AAM: 2024-07-16에 해당하는 데이터 없음
# AAM: 2024-07-17에 해당하는 데이터 없음
# AAM: 2024-07-18에 해당하는 데이터 없음
# AAM: 2024-07-19에 해당하는 데이터 없음
# AAM: 2024-07-22에 해당하는 데이터 없음
# AAM: 2024-07-23에 해당하는 데이터 없음
# AAM: 2024-07-24에 해당하는 데이터 없음
# AAM: 2024-07-25에 해당하는 데이터 없음
# AAM: 2024-07-26에 해당하는 데이터 없음
# AAM: 2024-07-29에 해당하는 데이터 없음
# AAM: 2024-07-30에 해당하는 데이터 없음
# AAM: 2024-07-31에 해당하는 데이터 없음
# AAM: 2024-08-01에 해당하는 데이터 없음
# AAM: 2024-08-02에 해당하는 데이터 없음
# AAM: 2024-08-05에 해당하는 데이터 없음
# AAM: 2024-08-06에 해당하는 데이터 없음
# AAM: 2024-08-07에 해당하는 데이터 없음
# AAM: 2024-08-08에 해당하는 데이터 없음
# AAM: 2024-08-09에 해당하는 데이터 없음
# AAM: 2024-08-12에 해당하는 데이터 없음
# AAM: 2024-08-13에 해당하는 데이터 없음
# AAM: 2024-08-14에 해당하는 데이터 없음
# AAM: 2024-08-15에 해당하는 데이터 없음
# AAM: 2024-08-16에 해당하는 데이터 없음
# AAM: 2024-08-19에 해당하는 데이터 없음
# AAM: 2024-08-20에 해당하는 데이터 없음
# AAM: 2024-08-21에 해당하는 데이터 없음
# AAM: 2024-08-22에 해당하는 데이터 없음
# AAM: 2024-08-23에 해당하는 데이터 없음
# AAM: 2024-08-26에 해당하는 데이터 없음
# AAM: 2024-08-27에 해당하는 데이터 없음
# AAM: 2024-08-28에 해당하는 데이터 없음
# AAM: 2024-08-29에 해당하는 데이터 없음
# AAM: 2024-08-30에 해당하는 데이터 없음
# AAM: 2024-09-03에 해당하는 데이터 없음
# AAM: 2024-09-04에 해당하는 데이터 없음
# AAM: 2024-09-05에 해당하는 데이터 없음
# AAM: 2024-09-06에 해당하는 데이터 없음
# AAM: 2024-09-09에 해당하는 데이터 없음
# AAM: 2024-09-10에 해당하는 데이터 없음
# AAM: 2024-09-11에 해당하는 데이터 없음
# AAM: 2024-09-12에 해당하는 데이터 없음
# AAM: 2024-09-13에 해당하는 데이터 없음
# AAM 처리 중 오류 발생: single positional indexer is out-of-bounds
# [11/17] Atlantic American Corporation Common Stock (AAME) 처리 중...
# AAME: Yahoo Finance에서 PBR값 0.3504 가져옴
# AAME: 시가총액 34,879,212 USD
# [12/17] Acadian Asset Management Inc. Common Stock (AAMI) 처리 중...
# AAMI: Yahoo Finance에서 PBR값 50.1354 가져옴
# AAMI: 시가총액 1,060,614,720 USD
# [13/17] Applied Optoelectronics Inc. Common Stock (AAOI) 처리 중...
# AAOI: Yahoo Finance에서 PBR값 2.8862 가져옴
# AAOI: 시가총액 940,891,328 USD
# [14/17] AAON Inc. Common Stock (AAON) 처리 중...
# AAON: Yahoo Finance에서 PBR값 9.5284 가져옴
# AAON: 시가총액 7,775,344,128 USD
# [15/17] Advance Auto Parts Inc. (AAP) 처리 중...
# AAP: Yahoo Finance에서 PBR값 1.4193 가져옴
# AAP: 시가총액 3,114,333,440 USD
# [16/17] Ascentage Pharma Group International American Depository Shares (AAPG) 처리 중...
# AAPG: Yahoo Finance에서 PBR값 32.8014 가져옴
# AAPG: 시가총액 2,417,363,456 USD
# AAPG: 2024-06-04에 해당하는 데이터 없음
# AAPG: 2024-06-05에 해당하는 데이터 없음
# AAPG: 2024-06-06에 해당하는 데이터 없음
# AAPG: 2024-06-07에 해당하는 데이터 없음
# AAPG: 2024-06-10에 해당하는 데이터 없음
# AAPG: 2024-06-11에 해당하는 데이터 없음
# AAPG: 2024-06-12에 해당하는 데이터 없음
# AAPG: 2024-06-13에 해당하는 데이터 없음
# AAPG: 2024-06-14에 해당하는 데이터 없음
# AAPG: 2024-06-17에 해당하는 데이터 없음
# AAPG: 2024-06-18에 해당하는 데이터 없음
# AAPG: 2024-06-20에 해당하는 데이터 없음
# AAPG: 2024-06-21에 해당하는 데이터 없음
# AAPG: 2024-06-24에 해당하는 데이터 없음
# AAPG: 2024-06-25에 해당하는 데이터 없음
# AAPG: 2024-06-26에 해당하는 데이터 없음
# AAPG: 2024-06-27에 해당하는 데이터 없음
# AAPG: 2024-06-28에 해당하는 데이터 없음
# AAPG: 2024-07-01에 해당하는 데이터 없음
# AAPG: 2024-07-02에 해당하는 데이터 없음
# AAPG: 2024-07-03에 해당하는 데이터 없음
# AAPG: 2024-07-05에 해당하는 데이터 없음
# AAPG: 2024-07-08에 해당하는 데이터 없음
# AAPG: 2024-07-09에 해당하는 데이터 없음
# AAPG: 2024-07-10에 해당하는 데이터 없음
# AAPG: 2024-07-11에 해당하는 데이터 없음
# AAPG: 2024-07-12에 해당하는 데이터 없음
# AAPG: 2024-07-15에 해당하는 데이터 없음
# AAPG: 2024-07-16에 해당하는 데이터 없음
# AAPG: 2024-07-17에 해당하는 데이터 없음
# AAPG: 2024-07-18에 해당하는 데이터 없음
# AAPG: 2024-07-19에 해당하는 데이터 없음
# AAPG: 2024-07-22에 해당하는 데이터 없음
# AAPG: 2024-07-23에 해당하는 데이터 없음
# AAPG: 2024-07-24에 해당하는 데이터 없음
# AAPG: 2024-07-25에 해당하는 데이터 없음
# AAPG: 2024-07-26에 해당하는 데이터 없음
# AAPG: 2024-07-29에 해당하는 데이터 없음
# AAPG: 2024-07-30에 해당하는 데이터 없음
# AAPG: 2024-07-31에 해당하는 데이터 없음
# AAPG: 2024-08-01에 해당하는 데이터 없음
# AAPG: 2024-08-02에 해당하는 데이터 없음
# AAPG: 2024-08-05에 해당하는 데이터 없음
# AAPG: 2024-08-06에 해당하는 데이터 없음
# AAPG: 2024-08-07에 해당하는 데이터 없음
# AAPG: 2024-08-08에 해당하는 데이터 없음
# AAPG: 2024-08-09에 해당하는 데이터 없음
# AAPG: 2024-08-12에 해당하는 데이터 없음
# AAPG: 2024-08-13에 해당하는 데이터 없음
# AAPG: 2024-08-14에 해당하는 데이터 없음
# AAPG: 2024-08-15에 해당하는 데이터 없음
# AAPG: 2024-08-16에 해당하는 데이터 없음
# AAPG: 2024-08-19에 해당하는 데이터 없음
# AAPG: 2024-08-20에 해당하는 데이터 없음
# AAPG: 2024-08-21에 해당하는 데이터 없음
# AAPG: 2024-08-22에 해당하는 데이터 없음
# AAPG: 2024-08-23에 해당하는 데이터 없음
# AAPG: 2024-08-26에 해당하는 데이터 없음
# AAPG: 2024-08-27에 해당하는 데이터 없음
# AAPG: 2024-08-28에 해당하는 데이터 없음
# AAPG: 2024-08-29에 해당하는 데이터 없음
# AAPG: 2024-08-30에 해당하는 데이터 없음
# AAPG: 2024-09-03에 해당하는 데이터 없음
# AAPG: 2024-09-04에 해당하는 데이터 없음
# AAPG: 2024-09-05에 해당하는 데이터 없음
# AAPG: 2024-09-06에 해당하는 데이터 없음
# AAPG: 2024-09-09에 해당하는 데이터 없음
# AAPG: 2024-09-10에 해당하는 데이터 없음
# AAPG: 2024-09-11에 해당하는 데이터 없음
# AAPG: 2024-09-12에 해당하는 데이터 없음
# AAPG: 2024-09-13에 해당하는 데이터 없음
# AAPG: 2024-09-16에 해당하는 데이터 없음
# AAPG: 2024-09-17에 해당하는 데이터 없음
# AAPG: 2024-09-18에 해당하는 데이터 없음
# AAPG: 2024-09-19에 해당하는 데이터 없음
# AAPG: 2024-09-20에 해당하는 데이터 없음
# AAPG: 2024-09-23에 해당하는 데이터 없음
# AAPG: 2024-09-24에 해당하는 데이터 없음
# AAPG: 2024-09-25에 해당하는 데이터 없음
# AAPG: 2024-09-26에 해당하는 데이터 없음
# AAPG: 2024-09-27에 해당하는 데이터 없음
# AAPG: 2024-09-30에 해당하는 데이터 없음
# AAPG: 2024-10-01에 해당하는 데이터 없음
# AAPG: 2024-10-02에 해당하는 데이터 없음
# AAPG: 2024-10-03에 해당하는 데이터 없음
# AAPG: 2024-10-04에 해당하는 데이터 없음
# AAPG: 2024-10-07에 해당하는 데이터 없음
# AAPG: 2024-10-08에 해당하는 데이터 없음
# AAPG: 2024-10-09에 해당하는 데이터 없음
# AAPG: 2024-10-10에 해당하는 데이터 없음
# AAPG: 2024-10-11에 해당하는 데이터 없음
# AAPG: 2024-10-14에 해당하는 데이터 없음
# AAPG: 2024-10-15에 해당하는 데이터 없음
# AAPG: 2024-10-16에 해당하는 데이터 없음
# AAPG: 2024-10-17에 해당하는 데이터 없음
# AAPG: 2024-10-18에 해당하는 데이터 없음
# AAPG: 2024-10-21에 해당하는 데이터 없음
# AAPG: 2024-10-22에 해당하는 데이터 없음
# AAPG: 2024-10-23에 해당하는 데이터 없음
# AAPG: 2024-10-24에 해당하는 데이터 없음
# AAPG: 2024-10-25에 해당하는 데이터 없음
# AAPG: 2024-10-28에 해당하는 데이터 없음
# AAPG: 2024-10-29에 해당하는 데이터 없음
# AAPG: 2024-10-30에 해당하는 데이터 없음
# AAPG: 2024-10-31에 해당하는 데이터 없음
# AAPG: 2024-11-01에 해당하는 데이터 없음
# AAPG: 2024-11-04에 해당하는 데이터 없음
# AAPG: 2024-11-05에 해당하는 데이터 없음
# AAPG: 2024-11-06에 해당하는 데이터 없음
# AAPG: 2024-11-07에 해당하는 데이터 없음
# AAPG: 2024-11-08에 해당하는 데이터 없음
# AAPG: 2024-11-11에 해당하는 데이터 없음
# AAPG: 2024-11-12에 해당하는 데이터 없음
# AAPG: 2024-11-13에 해당하는 데이터 없음
# AAPG: 2024-11-14에 해당하는 데이터 없음
# AAPG: 2024-11-15에 해당하는 데이터 없음
# AAPG: 2024-11-18에 해당하는 데이터 없음
# AAPG: 2024-11-19에 해당하는 데이터 없음
# AAPG: 2024-11-20에 해당하는 데이터 없음
# AAPG: 2024-11-21에 해당하는 데이터 없음
# AAPG: 2024-11-22에 해당하는 데이터 없음
# AAPG: 2024-11-25에 해당하는 데이터 없음
# AAPG: 2024-11-26에 해당하는 데이터 없음
# AAPG: 2024-11-27에 해당하는 데이터 없음
# AAPG: 2024-11-29에 해당하는 데이터 없음
# AAPG: 2024-12-02에 해당하는 데이터 없음
# AAPG: 2024-12-03에 해당하는 데이터 없음
# AAPG: 2024-12-04에 해당하는 데이터 없음
# AAPG: 2024-12-05에 해당하는 데이터 없음
# AAPG: 2024-12-06에 해당하는 데이터 없음
# AAPG: 2024-12-09에 해당하는 데이터 없음
# AAPG: 2024-12-10에 해당하는 데이터 없음
# AAPG: 2024-12-11에 해당하는 데이터 없음
# AAPG: 2024-12-12에 해당하는 데이터 없음
# AAPG: 2024-12-13에 해당하는 데이터 없음
# AAPG: 2024-12-16에 해당하는 데이터 없음
# AAPG: 2024-12-17에 해당하는 데이터 없음
# AAPG: 2024-12-18에 해당하는 데이터 없음
# AAPG: 2024-12-19에 해당하는 데이터 없음
# AAPG: 2024-12-20에 해당하는 데이터 없음
# AAPG: 2024-12-23에 해당하는 데이터 없음
# AAPG: 2024-12-24에 해당하는 데이터 없음
# AAPG: 2024-12-26에 해당하는 데이터 없음
# AAPG: 2024-12-27에 해당하는 데이터 없음
# AAPG: 2024-12-30에 해당하는 데이터 없음
# AAPG: 2024-12-31에 해당하는 데이터 없음
# AAPG: 2025-01-02에 해당하는 데이터 없음
# AAPG: 2025-01-03에 해당하는 데이터 없음
# AAPG: 2025-01-06에 해당하는 데이터 없음
# AAPG: 2025-01-07에 해당하는 데이터 없음
# AAPG: 2025-01-08에 해당하는 데이터 없음
# AAPG: 2025-01-10에 해당하는 데이터 없음
# AAPG: 2025-01-13에 해당하는 데이터 없음
# AAPG: 2025-01-14에 해당하는 데이터 없음
# AAPG: 2025-01-15에 해당하는 데이터 없음
# AAPG: 2025-01-16에 해당하는 데이터 없음
# AAPG: 2025-01-17에 해당하는 데이터 없음
# AAPG: 2025-01-21에 해당하는 데이터 없음
# AAPG: 2025-01-22에 해당하는 데이터 없음
# AAPG: 2025-01-23에 해당하는 데이터 없음
# AAPG 처리 중 오류 발생: single positional indexer is out-of-bounds
# [17/17] Apple Inc. Common Stock (AAPL) 처리 중...
# AAPL: Yahoo Finance에서 PBR값 45.4641 가져옴
# AAPL: 시가총액 3,036,000,026,624 USD
#
# 팩터 점수 계산 중...
# 팩터 점수 계산 완료
#
# 데이터가 processed_daily_5factor_model_20250604.csv에 저장되었습니다
#
# 데이터 요약:
# - 처리된 종목 수: 40
# - 처리된 일 수: 260
# - 총 행 수: 9779
# - 매수 신호 수: 2950
# - 매도 신호 수: 2695
#
# 전체 처리 완료! 총 실행 시간: 188.22초
